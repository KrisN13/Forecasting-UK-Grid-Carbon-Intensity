# %%
# Cell 1
import sys
sys.path.insert(0, '../src')

from carbon.pipeline import update_all

# %%
# Cell 2
update_all()
# Out:
# ...
# Carbon Intensity Pipeline
# ...
# No existing data — backfilling from 2022-01-01
# Fetching carbon intensity...
# Fetching generation mix...
#   35,604 new hourly records
# Saved → data\processed\df_carbon.parquet  (35,604 total rows)
#
# No existing temperature data — backfilling from 2022-01-01
# Fetching temperature from Open-Meteo...
#   36,768 new hourly temperature records
# Saved → data\processed\uk_temp_hourly.parquet  (36,768 total rows)
#
# Pipeline complete.
